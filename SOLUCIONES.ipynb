# %%
# Importacion de modulos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 📈 **3. Visualización básica con Matplotlib**
#
# **Objetivo**: Crear un gráfico de línea y un histograma.
#
# **Enunciado**:
# 1. Genera 100 números aleatorios con distribución normal (media = 0, desviación estándar = 1).
# 2. Haz un gráfico de líneas con los primeros 50 números.
# 3. Crea un histograma de los 100 números.
#
# **Mini-guía**:
# - Usa `np.random.normal()` para generar números.
#
# - Métodos útiles: `plt.plot()`, `plt.hist()`, `plt.show()`.

# %%
# 1. Genera 100 números aleatorios con distribución normal (media = 0, desviación estándar = 1).
numeros_aleatorias = np.random.normal(0, 1, 100)
print(numeros_aleatorias)

# 2. Haz un gráfico de líneas con los primeros 50 números.
plt.plot(numeros_aleatorias[:50], color='red', linestyle = '--')
plt.title('Grafica')
plt.grid(True)  # Añadir cuadrícula
plt.show()

# 3. Crea un histograma de los 100 números.
plt.hist(numeros_aleatorias, bins= 10, color='green')
plt.show()
# Out:
# [ 5.20372724e-01 -8.03088469e-01 -1.38492309e+00  1.60582895e+00
#   2.38349761e+00 -1.25519752e+00  1.11812009e+00  9.87356718e-01
#  -4.51327917e-01 -1.44941998e+00  5.08842146e-01 -4.22768094e-01
#   3.37227014e-01 -7.16898332e-01 -1.39704073e-01 -9.33605151e-01
#  -1.66695809e+00 -2.12749744e+00  4.32251686e-01  6.05351645e-01
#  -1.59891763e+00  6.38569293e-01 -8.41941147e-01 -6.21102976e-01
#  -8.94128033e-01  1.13787594e+00  2.64433029e-01 -9.34687853e-01
#  -1.60808034e+00  7.93914885e-01  6.54567155e-02  1.14324398e+00
#  -7.14432984e-01 -5.56925938e-01  1.80833515e-01 -1.08445124e+00
#  -1.75020213e+00 -4.11495185e-01  1.42912560e+00  1.35808457e+00
#   1.36980447e+00 -2.77792286e-01  9.87202460e-01 -5.26941903e-01
#   5.20399273e-01 -1.09605039e+00 -5.62326023e-01 -1.33028719e+00
#   2.84730027e-01 -2.47607799e-01  1.10775019e+00  4.90143359e-01
#  -6.28375071e-01  9.93793789e-01  3.96985628e-01 -8.20739562e-01
#   3.44090512e-02 -1.25182935e+00  2.97236467e-01  9.86863376e-01
#   1.02815025e+00  1.31378331e+00  2.41561834e-01  3.50284139e-01
#   7.23741507e-06  1.54162459e+00 -2.62035577e-01  1.52798523e+00
#  -4.86397430e-01  7.17534912e-01  7.03948002e-01 -1.52569613e+00
#  -3.71238677e-01 -1.10052404e+00  1.06864801e+00  4.66207074e-01
#  -1.72050992e+00  3.10100197e-01  5.61206665e-01 -1.23031533e-01
#   5.94077037e-01  1.25484442e+00  2.07361500e-01 -6.90924487e-01
#   7.39910082e-01  2.64931313e+00 -7.25845076e-01  5.85592822e-01
#  -4.03584254e-01 -6.20784424e-01 -8.52902768e-01 -9.71703059e-01
#   1.48982863e-01  9.34343280e-01  7.91040027e-01  1.35949304e-01
#   3.38564866e-01 -6.39648926e-01  1.41794269e+00 -1.03535176e+00]
